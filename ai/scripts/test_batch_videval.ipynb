# %%
from parse_video_ids_and_s3_urls import parse_video_url_map

# %%
tuples = parse_video_url_map(r'C:\Users\jeany\Desktop\NUS\Projects\TikTokJam-2025\ai\scripts\video_url_map.txt')

# %%
ids = [t[0] for t in tuples][:16]

# %%
import os
import sys
if '__file__' not in locals():
    __file__ = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))

from ai.evaluate_video_quality.main import evaluate_video_quality_batch

# %%
results = evaluate_video_quality_batch(ids)
print(results)
# Out:
# Found 1 files:Found 1 files:
#   - videos-embed/tiktok_7518294413584518418_video.mp4 (2345417 bytes)
#     URL: https://tiktok-video-embeddings.s3.ap-southeast-1.amazonaws.com/videos-embed/tiktok_7518294413584518418_video.mp4
# Starting download from S3: https://tiktok-video-embeddings.s3.ap-southeast-1.amazonaws.com/videos-embed/tiktok_7518294413584518418_video.mp4
#
#   - videos-embed/tiktok_7449999917877120299_video.mp4 (2817546 bytes)
#     URL: https://tiktok-video-embeddings.s3.ap-southeast-1.amazonaws.com/videos-embed/tiktok_7449999917877120299_video.mp4
# Starting download from S3: https://tiktok-video-embeddings.s3.ap-southeast-1.amazonaws.com/videos-embed/tiktok_7449999917877120299_video.mp4
# Found 1 files:
#   - videos-embed/tiktok_7525274214937529622_video.mp4 (15876742 bytes)
#     URL: https://tiktok-video-embeddings.s3.ap-southeast-1.amazonaws.com/videos-embed/tiktok_7525274214937529622_video.mp4
# ...
